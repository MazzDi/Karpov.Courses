# %%
import pandas as pd

# %%
pd.read_csv('/home/jupyter-n-korotkov/Karpov.Courses/lesson_8_pandas_optimization/user_retention.csv')
# Out:
#      Cohort    0         1         2         3         4         5         6  \
# 0   2010-12  1.0  0.381857  0.334388  0.387131  0.359705  0.396624  0.379747
# 1   2011-01  1.0  0.239905  0.282660  0.242280  0.327791  0.299287  0.261283
# 2   2011-02  1.0  0.247368  0.192105  0.278947  0.268421  0.247368  0.255263
# 3   2011-03  1.0  0.190909  0.254545  0.218182  0.231818  0.177273  0.263636
# 4   2011-04  1.0  0.227425  0.220736  0.210702  0.207358  0.237458  0.230769
# 5   2011-05  1.0  0.236559  0.172043  0.172043  0.215054  0.243728  0.265233
# 6   2011-06  1.0  0.208511  0.187234  0.272340  0.246809  0.336170  0.102128
# 7   2011-07  1.0  0.209424  0.204188  0.230366  0.272251  0.115183       NaN
# 8   2011-08  1.0  0.251497  0.251497  0.251497  0.137725       NaN       NaN
# 9   2011-09  1.0  0.298658  0.325503  0.120805       NaN       NaN       NaN
# 10  2011-10  1.0  0.264205  0.130682       NaN       NaN       NaN       NaN
# ...
