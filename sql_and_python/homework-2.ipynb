# %%
# import of libs
import pandahouse as ph
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# connection to clickhouse
connection = {  'host': 'http://clickhouse.beslan.pro:8080',        
                'database':'default',
                'user':'student', 
                'password':'dpo_python_2020'
             }

# %%
# query text, number of rows in ldn_listings
query = '''
SELECT count(*) rows_count
FROM ldn_listings
'''

# %%
# query to base and result
query_base = ph.read_clickhouse(query=query, connection=connection)
query_base
# Out:
#    rows_count
# 0       85207

# %%
# number of rows as integer
query_base.rows_count[0]
# Out:
# 85207

# %%
price_room_type = '''
SELECT
    id,
    room_type,
    toFloat32OrNull(replaceRegexpAll(price,'[$,]','')) as price_num

FROM ldn_listings
ORDER BY id ASC
LIMIT 1000
'''

# %%
q_price_room_type = ph.read_clickhouse(query=price_room_type, connection=connection)
q_price_room_type
# Out:
#          id        room_type  price_num
# 0     13913     Private room       65.0
# 1     15400  Entire home/apt      100.0
# 2     17402  Entire home/apt      300.0
# 3     17506     Private room      150.0
# 4     25023  Entire home/apt       65.0
# ..      ...              ...        ...
# 995  541081  Entire home/apt      110.0
# 996  541363  Entire home/apt      110.0
# 997  542231     Private room       65.0
# 998  542646  Entire home/apt      100.0
# 999  542754  Entire home/apt       80.0
#
# [1000 rows x 3 columns]

# %%
q_price_room_type.groupby('room_type', as_index=False) \
    .price_num.quantile(q=0.75)
# Out:
#          room_type  price_num
# 0  Entire home/apt     160.00
# 1       Hotel room     157.00
# 2     Private room      70.00
# 3      Shared room      69.25

# %%
avg_price_raiting = '''
SELECT
    id,
    room_type,
    toFloat32OrNull(replaceRegexpAll(price,'[$,]','')) as price_num,
    toFloat32OrNull(review_scores_rating) AS review_scores

FROM ldn_listings
WHERE review_scores_rating != ''
ORDER BY id ASC
LIMIT 1000
'''

# %%
q_avg_price_raiting = ph.read_clickhouse(query=avg_price_raiting, connection=connection)
q_avg_price_raiting
# Out:
#          id        room_type  price_num  review_scores
# 0     13913     Private room       65.0           97.0
# 1     15400  Entire home/apt      100.0           96.0
# 2     17402  Entire home/apt      300.0           94.0
# 3     25023  Entire home/apt       65.0           93.0
# 4     25123     Private room       29.0           96.0
# ..      ...              ...        ...            ...
# 995  616278  Entire home/apt      165.0          100.0
# 996  617678     Private room       99.0           93.0
# 997  618082     Private room       45.0          100.0
# 998  619010     Private room       20.0           88.0
# 999  619890  Entire home/apt      100.0           90.0
#
# [1000 rows x 4 columns]

# %%
avg_price = q_avg_price_raiting.groupby('room_type', as_index=False) \
    .agg({'price_num': 'mean', 'review_scores': 'mean'})
avg_price
# Out:
#          room_type   price_num  review_scores
# 0  Entire home/apt  135.882950      93.568787
# 1       Hotel room  134.000000      92.500000
# 2     Private room   54.642437      94.766205
# 3      Shared room   21.000000      90.000000

# %%
sns.scatterplot(data=avg_price, x="price_num", y="review_scores", hue="room_type")

# %%
emotions_query = '''
SELECT
    host_id,
    any(host_verifications) AS host_verifications

FROM ldn_listings
WHERE experiences_offered != 'none'
GROUP BY host_id
'''

# %%
q_emotions_query = ph.read_clickhouse(query=emotions_query, connection=connection)
q_emotions_query
# Out:
#        host_id                                 host_verifications
# 0       320901  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 1     21276165  ['email', 'phone', 'reviews', 'manual_offline'...
# 2      3722204  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 3     10961046  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 4     18974734  ['email', 'phone', 'reviews', 'jumio', 'govern...
# ...        ...                                                ...
# 1356   2110774  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 1357  19680548  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 1358   5396573  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1359  25357561  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 1360   1956888                      ['email', 'phone', 'reviews']
#
# [1361 rows x 2 columns]

# %%
q_emotions_query.host_verifications = q_emotions_query.host_verifications.str.strip("[]").str.replace("'",'').str.split(', ')

# %%
q_emotions_query
# Out:
#        host_id                                 host_verifications
# 0       320901  [email, phone, reviews, jumio, offline_governm...
# 1     21276165  [email, phone, reviews, manual_offline, jumio,...
# 2      3722204      [email, phone, reviews, jumio, government_id]
# 3     10961046      [email, phone, reviews, jumio, government_id]
# 4     18974734      [email, phone, reviews, jumio, government_id]
# ...        ...                                                ...
# 1356   2110774      [email, phone, reviews, jumio, government_id]
# 1357  19680548      [email, phone, reviews, jumio, government_id]
# 1358   5396573  [email, phone, facebook, reviews, jumio, offli...
# 1359  25357561      [email, phone, reviews, jumio, government_id]
# 1360   1956888                            [email, phone, reviews]
#
# [1361 rows x 2 columns]

# %%
final_emotions_query = q_emotions_query.explode('host_verifications')

# %%
final_emotions_query
# Out:
#        host_id     host_verifications
# 0       320901                  email
# 0       320901                  phone
# 0       320901                reviews
# 0       320901                  jumio
# 0       320901  offline_government_id
# ...        ...                    ...
# 1359  25357561                  jumio
# 1359  25357561          government_id
# 1360   1956888                  email
# 1360   1956888                  phone
# 1360   1956888                reviews
#
# [7976 rows x 2 columns]

# %%
final_emotions_query.host_verifications.value_counts()
# Out:
# phone                    1361
# email                    1345
# reviews                  1309
# government_id            1196
# jumio                    1115
# offline_government_id     469
# work_email                279
# facebook                  270
# selfie                    252
# identity_manual           227
# manual_offline             70
# google                     34
# kba                        27
# manual_online              16
# sent_id                     6
# Name: host_verifications, dtype: int64

# %%
roma_experience_query = '''
SELECT
    neighbourhood_cleansed,
    experiences_offered,
    count(experiences_offered) AS experiences_count

FROM ldn_listings
WHERE experiences_offered != 'none'
GROUP BY neighbourhood_cleansed, experiences_offered
ORDER BY experiences_count DESC

LIMIT 100
'''

# %%
q_roma_experience_query = ph.read_clickhouse(query=roma_experience_query, connection=connection)

# %%
final_roma = q_roma_experience_query.pivot(index='neighbourhood_cleansed', columns='experiences_offered', values='experiences_count')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(final_roma, cmap=sns.cubehelix_palette(as_cmap=True))

# %%
# Запрос для: Выгрузите данные о ценах за ночь для разных типов жилья, 
# для которых также доступен какой-либо вид впечатления. 

room_price_roma_query = '''
SELECT
    room_type,
    toFloat32OrNull(replaceRegexpAll(price,'[$,]','')) AS price,
    experiences_offered

FROM ldn_listings
WHERE experiences_offered != 'none'
'''

# %%
q_room_price_roma_query = ph.read_clickhouse(query=room_price_roma_query, connection=connection)

# %%
q_room_price_roma_query['price_log'] = np.log(q_room_price_roma_query.price)

# %%
q_room_price_roma_query
# Out:
#             room_type  price experiences_offered  price_log
# 0        Private room   65.0            business   4.174387
# 1     Entire home/apt  100.0            romantic   4.605170
# 2        Private room  150.0            business   5.010635
# 3        Private room   45.0            business   3.806663
# 4        Private room   25.0            business   3.218876
# ...               ...    ...                 ...        ...
# 1543  Entire home/apt  100.0              family   4.605170
# 1544  Entire home/apt  125.0            business   4.828314
# 1545  Entire home/apt  185.0            business   5.220356
# 1546  Entire home/apt  110.0            business   4.700480
# 1547     Private room   39.0              social   3.663562
#
# [1548 rows x 4 columns]

# %%
sns.displot(data = q_room_price_roma_query, x = 'price', hue = 'room_type', height=10)

# %%
sns.displot(data = q_room_price_roma_query, x = 'price_log', hue = 'room_type', height=10)

# %%
sns.displot(
    q_room_price_roma_query, x="price", hue = 'room_type', height=10)

# %%
# Выгрузите данные о цене, типе жилья и дате первого отзыва, начиная со 2 января 2010 года.
query_price_date = '''
SELECT
    room_type,
    toFloat32OrNull(replaceRegexpAll(price,'[$,]','')) AS price,
    first_review

FROM ldn_listings
WHERE first_review > '2010-01-01'
LIMIT 1000
'''

# %%
df_query_price_date = ph.read_clickhouse(query=query_price_date, connection=connection)

# %%
df_query_price_date.dtypes
# Out:
# room_type               object
# price                  float32
# first_review    datetime64[ns]
# dtype: object

# %%
df_query_price_date.first_review = pd.to_datetime(df_query_price_date.first_review)

# %%
df_query_price_date['year'] = df_query_price_date.first_review.dt.year

# %%
final_df_price_date = df_query_price_date.groupby(['room_type', 'year'], as_index=False) \
    .agg({'price' : 'mean'}) \
    .sort_values('year', ascending=True)
final_df_price_date.head()
# Out:
#           room_type  year       price
# 0   Entire home/apt  2010  103.500000
# 13     Private room  2010   56.428570
# 11       Hotel room  2010   88.000000
# 1   Entire home/apt  2011  128.792450
# 14     Private room  2011   52.607143

# %%
sns.lineplot(data=final_df_price_date, x="year", y="price", hue='room_type')

# %%
for index, rows in q_room_price_roma_query.iterrows():
    print(f'index is {index}, row is:\n{rows}\n')
# Out:
# index is 0, row is:
# room_type              Private room
# price                            65
# experiences_offered        business
# price_log                   4.17439
# Name: 0, dtype: object
#
# index is 1, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered           romantic
# price_log                      4.60517
# Name: 1, dtype: object
#
# index is 2, row is:
# room_type              Private room
# price                           150
# experiences_offered        business
# price_log                   5.01064
# Name: 2, dtype: object
#
# index is 3, row is:
# room_type              Private room
# price                            45
# experiences_offered        business
# price_log                   3.80666
# Name: 3, dtype: object
#
# index is 4, row is:
# room_type              Private room
# price                            25
# experiences_offered        business
# price_log                   3.21888
# Name: 4, dtype: object
#
# index is 5, row is:
# room_type              Private room
# price                            60
# experiences_offered        business
# price_log                   4.09434
# Name: 5, dtype: object
#
# index is 6, row is:
# room_type              Private room
# price                           125
# experiences_offered          social
# price_log                   4.82831
# Name: 6, dtype: object
#
# index is 7, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered           romantic
# price_log                      4.60517
# Name: 7, dtype: object
#
# index is 8, row is:
# room_type              Private room
# price                            39
# experiences_offered          social
# price_log                   3.66356
# Name: 8, dtype: object
#
# index is 9, row is:
# room_type              Entire home/apt
# price                               85
# experiences_offered           romantic
# price_log                      4.44265
# Name: 9, dtype: object
#
# index is 10, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 10, dtype: object
#
# index is 11, row is:
# room_type              Private room
# price                            80
# experiences_offered        business
# price_log                   4.38203
# Name: 11, dtype: object
#
# index is 12, row is:
# room_type              Private room
# price                            45
# experiences_offered          social
# price_log                   3.80666
# Name: 12, dtype: object
#
# index is 13, row is:
# room_type              Entire home/apt
# price                               52
# experiences_offered           business
# price_log                      3.95124
# Name: 13, dtype: object
#
# index is 14, row is:
# room_type              Entire home/apt
# price                              400
# experiences_offered             family
# price_log                      5.99146
# Name: 14, dtype: object
#
# index is 15, row is:
# room_type              Private room
# price                            29
# experiences_offered          social
# price_log                    3.3673
# Name: 15, dtype: object
#
# index is 16, row is:
# room_type              Entire home/apt
# price                              133
# experiences_offered             family
# price_log                      4.89035
# Name: 16, dtype: object
#
# index is 17, row is:
# room_type              Hotel room
# price                         180
# experiences_offered      business
# price_log                 5.19296
# Name: 17, dtype: object
#
# index is 18, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered           business
# price_log                      4.70048
# Name: 18, dtype: object
#
# index is 19, row is:
# room_type              Private room
# price                            99
# experiences_offered        business
# price_log                   4.59512
# Name: 19, dtype: object
#
# index is 20, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 20, dtype: object
#
# index is 21, row is:
# room_type              Entire home/apt
# price                              139
# experiences_offered             family
# price_log                      4.93447
# Name: 21, dtype: object
#
# index is 22, row is:
# room_type              Private room
# price                            35
# experiences_offered          social
# price_log                   3.55535
# Name: 22, dtype: object
#
# index is 23, row is:
# room_type              Private room
# price                            75
# experiences_offered        business
# price_log                   4.31749
# Name: 23, dtype: object
#
# index is 24, row is:
# room_type              Private room
# price                            55
# experiences_offered          social
# price_log                   4.00733
# Name: 24, dtype: object
#
# index is 25, row is:
# room_type              Private room
# price                            95
# experiences_offered        business
# price_log                   4.55388
# Name: 25, dtype: object
#
# index is 26, row is:
# room_type              Entire home/apt
# price                              250
# experiences_offered             family
# price_log                      5.52146
# Name: 26, dtype: object
#
# index is 27, row is:
# room_type              Entire home/apt
# price                               99
# experiences_offered             family
# price_log                      4.59512
# Name: 27, dtype: object
#
# index is 28, row is:
# room_type              Private room
# price                            45
# experiences_offered          family
# price_log                   3.80666
# Name: 28, dtype: object
#
# index is 29, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered             family
# price_log                      4.70048
# Name: 29, dtype: object
#
# index is 30, row is:
# room_type              Entire home/apt
# price                               95
# experiences_offered           romantic
# price_log                      4.55388
# Name: 30, dtype: object
#
# index is 31, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             social
# price_log                      4.78749
# Name: 31, dtype: object
#
# index is 32, row is:
# room_type              Private room
# price                            50
# experiences_offered        business
# price_log                   3.91202
# Name: 32, dtype: object
#
# index is 33, row is:
# room_type              Private room
# price                            35
# experiences_offered          social
# price_log                   3.55535
# Name: 33, dtype: object
#
# index is 34, row is:
# room_type              Private room
# price                            39
# experiences_offered          social
# price_log                   3.66356
# Name: 34, dtype: object
#
# index is 35, row is:
# room_type              Private room
# price                            45
# experiences_offered        business
# price_log                   3.80666
# Name: 35, dtype: object
#
# index is 36, row is:
# room_type              Entire home/apt
# price                              165
# experiences_offered           romantic
# price_log                      5.10595
# Name: 36, dtype: object
#
# index is 37, row is:
# room_type              Entire home/apt
# price                              130
# experiences_offered             family
# price_log                      4.86753
# Name: 37, dtype: object
#
# index is 38, row is:
# room_type              Private room
# price                            48
# experiences_offered          social
# price_log                    3.8712
# Name: 38, dtype: object
#
# index is 39, row is:
# room_type              Private room
# price                            60
# experiences_offered          social
# price_log                   4.09434
# Name: 39, dtype: object
#
# index is 40, row is:
# room_type              Entire home/apt
# price                              123
# experiences_offered             family
# price_log                      4.81218
# Name: 40, dtype: object
#
# index is 41, row is:
# room_type              Entire home/apt
# price                              109
# experiences_offered             family
# price_log                      4.69135
# Name: 41, dtype: object
#
# index is 42, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered             family
# price_log                      4.70048
# Name: 42, dtype: object
#
# index is 43, row is:
# room_type              Private room
# price                            58
# experiences_offered        business
# price_log                   4.06044
# Name: 43, dtype: object
#
# index is 44, row is:
# room_type              Entire home/apt
# price                               91
# experiences_offered             family
# price_log                      4.51086
# Name: 44, dtype: object
#
# index is 45, row is:
# room_type              Private room
# price                            29
# experiences_offered          social
# price_log                    3.3673
# Name: 45, dtype: object
#
# index is 46, row is:
# room_type              Private room
# price                            38
# experiences_offered          social
# price_log                   3.63759
# Name: 46, dtype: object
#
# index is 47, row is:
# room_type              Private room
# price                            55
# experiences_offered          social
# price_log                   4.00733
# Name: 47, dtype: object
#
# index is 48, row is:
# room_type              Entire home/apt
# price                               65
# experiences_offered           romantic
# price_log                      4.17439
# Name: 48, dtype: object
#
# index is 49, row is:
# room_type              Private room
# price                            31
# experiences_offered        business
# price_log                   3.43399
# Name: 49, dtype: object
#
# index is 50, row is:
# room_type              Private room
# price                            45
# experiences_offered          family
# price_log                   3.80666
# Name: 50, dtype: object
#
# index is 51, row is:
# room_type              Private room
# price                            45
# experiences_offered          family
# price_log                   3.80666
# Name: 51, dtype: object
#
# index is 52, row is:
# room_type              Private room
# price                            29
# experiences_offered        business
# price_log                    3.3673
# Name: 52, dtype: object
#
# index is 53, row is:
# room_type              Private room
# price                            34
# experiences_offered        business
# price_log                   3.52636
# Name: 53, dtype: object
#
# index is 54, row is:
# room_type              Entire home/apt
# price                              190
# experiences_offered             family
# price_log                      5.24702
# Name: 54, dtype: object
#
# index is 55, row is:
# room_type              Entire home/apt
# price                               70
# experiences_offered           business
# price_log                       4.2485
# Name: 55, dtype: object
#
# index is 56, row is:
# room_type              Entire home/apt
# price                               85
# experiences_offered             social
# price_log                      4.44265
# Name: 56, dtype: object
#
# index is 57, row is:
# room_type              Private room
# price                            26
# experiences_offered          social
# price_log                    3.2581
# Name: 57, dtype: object
#
# index is 58, row is:
# room_type              Private room
# price                            58
# experiences_offered          social
# price_log                   4.06044
# Name: 58, dtype: object
#
# index is 59, row is:
# room_type              Private room
# price                           100
# experiences_offered          social
# price_log                   4.60517
# Name: 59, dtype: object
#
# index is 60, row is:
# room_type              Private room
# price                            60
# experiences_offered        business
# price_log                   4.09434
# Name: 60, dtype: object
#
# index is 61, row is:
# room_type              Private room
# price                           115
# experiences_offered        business
# price_log                   4.74493
# Name: 61, dtype: object
#
# index is 62, row is:
# room_type              Entire home/apt
# price                              149
# experiences_offered           business
# price_log                      5.00395
# Name: 62, dtype: object
#
# index is 63, row is:
# room_type              Private room
# price                            45
# experiences_offered          family
# price_log                   3.80666
# Name: 63, dtype: object
#
# index is 64, row is:
# room_type              Private room
# price                            55
# experiences_offered          family
# price_log                   4.00733
# Name: 64, dtype: object
#
# index is 65, row is:
# room_type              Entire home/apt
# price                              175
# experiences_offered             family
# price_log                      5.16479
# Name: 65, dtype: object
#
# index is 66, row is:
# room_type              Private room
# price                            95
# experiences_offered        business
# price_log                   4.55388
# Name: 66, dtype: object
#
# index is 67, row is:
# room_type              Entire home/apt
# price                              119
# experiences_offered             social
# price_log                      4.77912
# Name: 67, dtype: object
#
# index is 68, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 68, dtype: object
#
# index is 69, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered             family
# price_log                      4.94164
# Name: 69, dtype: object
#
# index is 70, row is:
# room_type              Private room
# price                            65
# experiences_offered          family
# price_log                   4.17439
# Name: 70, dtype: object
#
# index is 71, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 71, dtype: object
#
# index is 72, row is:
# room_type              Private room
# price                            60
# experiences_offered          family
# price_log                   4.09434
# Name: 72, dtype: object
#
# index is 73, row is:
# room_type              Private room
# price                            60
# experiences_offered        business
# price_log                   4.09434
# Name: 73, dtype: object
#
# index is 74, row is:
# room_type              Private room
# price                            39
# experiences_offered        business
# price_log                   3.66356
# Name: 74, dtype: object
#
# index is 75, row is:
# room_type              Private room
# price                            65
# experiences_offered          social
# price_log                   4.17439
# Name: 75, dtype: object
#
# index is 76, row is:
# room_type              Private room
# price                            44
# experiences_offered        business
# price_log                   3.78419
# Name: 76, dtype: object
#
# index is 77, row is:
# room_type              Entire home/apt
# price                               85
# experiences_offered           romantic
# price_log                      4.44265
# Name: 77, dtype: object
#
# index is 78, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered             family
# price_log                      4.94164
# Name: 78, dtype: object
#
# index is 79, row is:
# room_type              Private room
# price                            60
# experiences_offered          social
# price_log                   4.09434
# Name: 79, dtype: object
#
# index is 80, row is:
# room_type              Private room
# price                            75
# experiences_offered        business
# price_log                   4.31749
# Name: 80, dtype: object
#
# index is 81, row is:
# room_type              Private room
# price                           125
# experiences_offered        business
# price_log                   4.82831
# Name: 81, dtype: object
#
# index is 82, row is:
# room_type              Private room
# price                            49
# experiences_offered          social
# price_log                   3.89182
# Name: 82, dtype: object
#
# index is 83, row is:
# room_type              Private room
# price                            29
# experiences_offered          social
# price_log                    3.3673
# Name: 83, dtype: object
#
# index is 84, row is:
# room_type              Private room
# price                            49
# experiences_offered          social
# price_log                   3.89182
# Name: 84, dtype: object
#
# index is 85, row is:
# room_type              Private room
# price                            33
# experiences_offered          social
# price_log                   3.49651
# Name: 85, dtype: object
#
# index is 86, row is:
# room_type              Private room
# price                            42
# experiences_offered        business
# price_log                   3.73767
# Name: 86, dtype: object
#
# index is 87, row is:
# room_type              Private room
# price                            80
# experiences_offered        business
# price_log                   4.38203
# Name: 87, dtype: object
#
# index is 88, row is:
# room_type              Private room
# price                            40
# experiences_offered          social
# price_log                   3.68888
# Name: 88, dtype: object
#
# index is 89, row is:
# room_type              Private room
# price                            70
# experiences_offered          social
# price_log                    4.2485
# Name: 89, dtype: object
#
# index is 90, row is:
# room_type              Private room
# price                            60
# experiences_offered        business
# price_log                   4.09434
# Name: 90, dtype: object
#
# index is 91, row is:
# room_type              Private room
# price                            65
# experiences_offered        business
# price_log                   4.17439
# Name: 91, dtype: object
#
# index is 92, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 92, dtype: object
#
# index is 93, row is:
# room_type              Private room
# price                            49
# experiences_offered          social
# price_log                   3.89182
# Name: 93, dtype: object
#
# index is 94, row is:
# room_type              Private room
# price                            40
# experiences_offered          social
# price_log                   3.68888
# Name: 94, dtype: object
#
# index is 95, row is:
# room_type              Entire home/apt
# price                              155
# experiences_offered             family
# price_log                      5.04343
# Name: 95, dtype: object
#
# index is 96, row is:
# room_type              Private room
# price                            32
# experiences_offered          social
# price_log                   3.46574
# Name: 96, dtype: object
#
# index is 97, row is:
# room_type              Entire home/apt
# price                              195
# experiences_offered           business
# price_log                        5.273
# Name: 97, dtype: object
#
# index is 98, row is:
# room_type              Entire home/apt
# price                               90
# experiences_offered             social
# price_log                      4.49981
# Name: 98, dtype: object
#
# index is 99, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered             social
# price_log                      4.94164
# Name: 99, dtype: object
#
# index is 100, row is:
# room_type              Private room
# price                            85
# experiences_offered          social
# price_log                   4.44265
# Name: 100, dtype: object
#
# index is 101, row is:
# room_type              Entire home/apt
# price                              350
# experiences_offered           business
# price_log                      5.85793
# Name: 101, dtype: object
#
# index is 102, row is:
# room_type              Entire home/apt
# price                              350
# experiences_offered           business
# price_log                      5.85793
# Name: 102, dtype: object
#
# index is 103, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered           business
# price_log                      4.70048
# Name: 103, dtype: object
#
# index is 104, row is:
# room_type              Entire home/apt
# price                              145
# experiences_offered           business
# price_log                      4.97673
# Name: 104, dtype: object
#
# index is 105, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered           romantic
# price_log                      5.29832
# Name: 105, dtype: object
#
# index is 106, row is:
# room_type              Private room
# price                            65
# experiences_offered        business
# price_log                   4.17439
# Name: 106, dtype: object
#
# index is 107, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered             social
# price_log                      4.94164
# Name: 107, dtype: object
#
# index is 108, row is:
# room_type              Private room
# price                            21
# experiences_offered        business
# price_log                   3.04452
# Name: 108, dtype: object
#
# index is 109, row is:
# room_type              Private room
# price                            25
# experiences_offered          social
# price_log                   3.21888
# Name: 109, dtype: object
#
# index is 110, row is:
# room_type              Private room
# price                            42
# experiences_offered          social
# price_log                   3.73767
# Name: 110, dtype: object
#
# index is 111, row is:
# room_type              Entire home/apt
# price                              150
# experiences_offered           business
# price_log                      5.01064
# Name: 111, dtype: object
#
# index is 112, row is:
# room_type              Private room
# price                            48
# experiences_offered        business
# price_log                    3.8712
# Name: 112, dtype: object
#
# index is 113, row is:
# room_type              Private room
# price                            50
# experiences_offered          social
# price_log                   3.91202
# Name: 113, dtype: object
#
# index is 114, row is:
# room_type              Private room
# price                            35
# experiences_offered        business
# price_log                   3.55535
# Name: 114, dtype: object
#
# index is 115, row is:
# room_type              Private room
# price                            50
# experiences_offered          family
# price_log                   3.91202
# Name: 115, dtype: object
#
# index is 116, row is:
# room_type              Entire home/apt
# price                              300
# experiences_offered             family
# price_log                      5.70378
# Name: 116, dtype: object
#
# index is 117, row is:
# room_type              Entire home/apt
# price                              320
# experiences_offered             family
# price_log                      5.76832
# Name: 117, dtype: object
#
# index is 118, row is:
# room_type              Entire home/apt
# price                              250
# experiences_offered             family
# price_log                      5.52146
# Name: 118, dtype: object
#
# index is 119, row is:
# room_type              Entire home/apt
# price                              299
# experiences_offered           romantic
# price_log                      5.70044
# Name: 119, dtype: object
#
# index is 120, row is:
# room_type              Entire home/apt
# price                              125
# experiences_offered           business
# price_log                      4.82831
# Name: 120, dtype: object
#
# index is 121, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered           business
# price_log                      5.29832
# Name: 121, dtype: object
#
# index is 122, row is:
# room_type              Private room
# price                            50
# experiences_offered          social
# price_log                   3.91202
# Name: 122, dtype: object
#
# index is 123, row is:
# room_type              Private room
# price                            32
# experiences_offered        business
# price_log                   3.46574
# Name: 123, dtype: object
#
# index is 124, row is:
# room_type              Entire home/apt
# price                              125
# experiences_offered           romantic
# price_log                      4.82831
# Name: 124, dtype: object
#
# index is 125, row is:
# room_type              Private room
# price                            44
# experiences_offered          social
# price_log                   3.78419
# Name: 125, dtype: object
#
# index is 126, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 126, dtype: object
#
# index is 127, row is:
# room_type              Entire home/apt
# price                              127
# experiences_offered             family
# price_log                      4.84419
# Name: 127, dtype: object
#
# index is 128, row is:
# room_type              Entire home/apt
# price                              149
# experiences_offered           business
# price_log                      5.00395
# Name: 128, dtype: object
#
# index is 129, row is:
# room_type              Entire home/apt
# price                              199
# experiences_offered             family
# price_log                       5.2933
# Name: 129, dtype: object
#
# index is 130, row is:
# room_type              Private room
# price                            33
# experiences_offered          social
# price_log                   3.49651
# Name: 130, dtype: object
#
# index is 131, row is:
# room_type              Private room
# price                            95
# experiences_offered        business
# price_log                   4.55388
# Name: 131, dtype: object
#
# index is 132, row is:
# room_type              Entire home/apt
# price                              210
# experiences_offered           business
# price_log                      5.34711
# Name: 132, dtype: object
#
# index is 133, row is:
# room_type              Private room
# price                            39
# experiences_offered        business
# price_log                   3.66356
# Name: 133, dtype: object
#
# index is 134, row is:
# room_type              Entire home/apt
# price                              175
# experiences_offered           business
# price_log                      5.16479
# Name: 134, dtype: object
#
# index is 135, row is:
# room_type              Entire home/apt
# price                               65
# experiences_offered             family
# price_log                      4.17439
# Name: 135, dtype: object
#
# index is 136, row is:
# room_type              Private room
# price                            50
# experiences_offered          social
# price_log                   3.91202
# Name: 136, dtype: object
#
# index is 137, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered           business
# price_log                      4.60517
# Name: 137, dtype: object
#
# index is 138, row is:
# room_type              Private room
# price                            36
# experiences_offered        business
# price_log                   3.58352
# Name: 138, dtype: object
#
# index is 139, row is:
# room_type              Entire home/apt
# price                               90
# experiences_offered           business
# price_log                      4.49981
# Name: 139, dtype: object
#
# index is 140, row is:
# room_type              Entire home/apt
# price                              180
# experiences_offered             family
# price_log                      5.19296
# Name: 140, dtype: object
#
# index is 141, row is:
# room_type              Private room
# price                            40
# experiences_offered        business
# price_log                   3.68888
# Name: 141, dtype: object
#
# index is 142, row is:
# room_type              Private room
# price                            60
# experiences_offered          social
# price_log                   4.09434
# Name: 142, dtype: object
#
# index is 143, row is:
# room_type              Private room
# price                            70
# experiences_offered          social
# price_log                    4.2485
# Name: 143, dtype: object
#
# index is 144, row is:
# room_type              Private room
# price                            29
# experiences_offered          social
# price_log                    3.3673
# Name: 144, dtype: object
#
# index is 145, row is:
# room_type              Entire home/apt
# price                              139
# experiences_offered           business
# price_log                      4.93447
# Name: 145, dtype: object
#
# index is 146, row is:
# room_type              Entire home/apt
# price                              160
# experiences_offered           romantic
# price_log                      5.07517
# Name: 146, dtype: object
#
# index is 147, row is:
# room_type              Private room
# price                            27
# experiences_offered          social
# price_log                   3.29584
# Name: 147, dtype: object
#
# index is 148, row is:
# room_type              Private room
# price                            35
# experiences_offered        business
# price_log                   3.55535
# Name: 148, dtype: object
#
# index is 149, row is:
# room_type              Entire home/apt
# price                               75
# experiences_offered           business
# price_log                      4.31749
# Name: 149, dtype: object
#
# index is 150, row is:
# room_type              Private room
# price                            66
# experiences_offered        business
# price_log                   4.18965
# Name: 150, dtype: object
#
# index is 151, row is:
# room_type              Entire home/apt
# price                              304
# experiences_offered             family
# price_log                      5.71703
# Name: 151, dtype: object
#
# index is 152, row is:
# room_type              Entire home/apt
# price                              901
# experiences_offered             family
# price_log                      6.80351
# Name: 152, dtype: object
#
# index is 153, row is:
# room_type              Private room
# price                            37
# experiences_offered          social
# price_log                   3.61092
# Name: 153, dtype: object
#
# index is 154, row is:
# room_type              Private room
# price                            75
# experiences_offered        business
# price_log                   4.31749
# Name: 154, dtype: object
#
# index is 155, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered             family
# price_log                      4.94164
# Name: 155, dtype: object
#
# index is 156, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered           business
# price_log                      4.94164
# Name: 156, dtype: object
#
# index is 157, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered             family
# price_log                      4.70048
# Name: 157, dtype: object
#
# index is 158, row is:
# room_type              Private room
# price                            65
# experiences_offered          family
# price_log                   4.17439
# Name: 158, dtype: object
#
# index is 159, row is:
# room_type              Entire home/apt
# price                              149
# experiences_offered             family
# price_log                      5.00395
# Name: 159, dtype: object
#
# index is 160, row is:
# room_type              Private room
# price                            42
# experiences_offered          family
# price_log                   3.73767
# Name: 160, dtype: object
#
# index is 161, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered             family
# price_log                      5.29832
# Name: 161, dtype: object
#
# index is 162, row is:
# room_type              Entire home/apt
# price                              109
# experiences_offered           business
# price_log                      4.69135
# Name: 162, dtype: object
#
# index is 163, row is:
# room_type              Entire home/apt
# price                               95
# experiences_offered             social
# price_log                      4.55388
# Name: 163, dtype: object
#
# index is 164, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered           romantic
# price_log                      4.60517
# Name: 164, dtype: object
#
# index is 165, row is:
# room_type              Entire home/apt
# price                              155
# experiences_offered             family
# price_log                      5.04343
# Name: 165, dtype: object
#
# index is 166, row is:
# room_type              Private room
# price                            41
# experiences_offered          social
# price_log                   3.71357
# Name: 166, dtype: object
#
# index is 167, row is:
# room_type              Entire home/apt
# price                              180
# experiences_offered             family
# price_log                      5.19296
# Name: 167, dtype: object
#
# index is 168, row is:
# room_type              Entire home/apt
# price                              180
# experiences_offered           business
# price_log                      5.19296
# Name: 168, dtype: object
#
# index is 169, row is:
# room_type              Entire home/apt
# price                               45
# experiences_offered             family
# price_log                      3.80666
# Name: 169, dtype: object
#
# index is 170, row is:
# room_type              Entire home/apt
# price                              149
# experiences_offered           business
# price_log                      5.00395
# Name: 170, dtype: object
#
# index is 171, row is:
# room_type              Private room
# price                            29
# experiences_offered          social
# price_log                    3.3673
# Name: 171, dtype: object
#
# index is 172, row is:
# room_type              Entire home/apt
# price                               95
# experiences_offered           business
# price_log                      4.55388
# Name: 172, dtype: object
#
# index is 173, row is:
# room_type              Entire home/apt
# price                              180
# experiences_offered             social
# price_log                      5.19296
# Name: 173, dtype: object
#
# index is 174, row is:
# room_type              Private room
# price                            35
# experiences_offered        business
# price_log                   3.55535
# Name: 174, dtype: object
#
# index is 175, row is:
# room_type              Private room
# price                            45
# experiences_offered        business
# price_log                   3.80666
# Name: 175, dtype: object
#
# index is 176, row is:
# room_type              Private room
# price                            59
# experiences_offered        business
# price_log                   4.07754
# Name: 176, dtype: object
#
# index is 177, row is:
# room_type              Private room
# price                            58
# experiences_offered          family
# price_log                   4.06044
# Name: 177, dtype: object
#
# index is 178, row is:
# room_type              Private room
# price                            44
# experiences_offered        business
# price_log                   3.78419
# Name: 178, dtype: object
#
# index is 179, row is:
# room_type              Private room
# price                            50
# experiences_offered        business
# price_log                   3.91202
# Name: 179, dtype: object
#
# index is 180, row is:
# room_type              Private room
# price                            45
# experiences_offered          social
# price_log                   3.80666
# Name: 180, dtype: object
#
# index is 181, row is:
# room_type              Entire home/apt
# price                              190
# experiences_offered           romantic
# price_log                      5.24702
# Name: 181, dtype: object
#
# index is 182, row is:
# room_type              Private room
# price                            26
# experiences_offered          social
# price_log                    3.2581
# Name: 182, dtype: object
#
# index is 183, row is:
# room_type              Private room
# price                            44
# experiences_offered        business
# price_log                   3.78419
# Name: 183, dtype: object
#
# index is 184, row is:
# room_type              Entire home/apt
# price                              150
# experiences_offered           business
# price_log                      5.01064
# Name: 184, dtype: object
#
# index is 185, row is:
# room_type              Private room
# price                            58
# experiences_offered          social
# price_log                   4.06044
# Name: 185, dtype: object
#
# index is 186, row is:
# room_type              Entire home/apt
# price                              150
# experiences_offered             family
# price_log                      5.01064
# Name: 186, dtype: object
#
# index is 187, row is:
# room_type              Private room
# price                            51
# experiences_offered        business
# price_log                   3.93183
# Name: 187, dtype: object
#
# index is 188, row is:
# room_type              Private room
# price                            99
# experiences_offered        business
# price_log                   4.59512
# Name: 188, dtype: object
#
# index is 189, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 189, dtype: object
#
# index is 190, row is:
# room_type              Entire home/apt
# price                              135
# experiences_offered           business
# price_log                      4.90527
# Name: 190, dtype: object
#
# index is 191, row is:
# room_type              Private room
# price                            25
# experiences_offered          social
# price_log                   3.21888
# Name: 191, dtype: object
#
# index is 192, row is:
# room_type              Entire home/apt
# price                               75
# experiences_offered             social
# price_log                      4.31749
# Name: 192, dtype: object
#
# index is 193, row is:
# room_type              Entire home/apt
# price                              109
# experiences_offered           business
# price_log                      4.69135
# Name: 193, dtype: object
#
# index is 194, row is:
# room_type              Private room
# price                            42
# experiences_offered        business
# price_log                   3.73767
# Name: 194, dtype: object
#
# index is 195, row is:
# room_type              Entire home/apt
# price                               75
# experiences_offered           business
# price_log                      4.31749
# Name: 195, dtype: object
#
# index is 196, row is:
# room_type              Entire home/apt
# price                               69
# experiences_offered             family
# price_log                      4.23411
# Name: 196, dtype: object
#
# index is 197, row is:
# room_type              Entire home/apt
# price                               90
# experiences_offered           romantic
# price_log                      4.49981
# Name: 197, dtype: object
#
# index is 198, row is:
# room_type              Entire home/apt
# price                              150
# experiences_offered           business
# price_log                      5.01064
# Name: 198, dtype: object
#
# index is 199, row is:
# room_type              Entire home/apt
# price                              155
# experiences_offered           business
# price_log                      5.04343
# Name: 199, dtype: object
#
# index is 200, row is:
# room_type              Private room
# price                            43
# experiences_offered          social
# price_log                    3.7612
# Name: 200, dtype: object
#
# index is 201, row is:
# room_type              Private room
# price                            57
# experiences_offered        business
# price_log                   4.04305
# Name: 201, dtype: object
#
# index is 202, row is:
# room_type              Entire home/apt
# price                              245
# experiences_offered           romantic
# price_log                      5.50126
# Name: 202, dtype: object
#
# index is 203, row is:
# room_type              Entire home/apt
# price                               89
# experiences_offered             social
# price_log                      4.48864
# Name: 203, dtype: object
#
# index is 204, row is:
# room_type              Private room
# price                            35
# experiences_offered          social
# price_log                   3.55535
# Name: 204, dtype: object
#
# index is 205, row is:
# room_type              Hotel room
# price                         120
# experiences_offered        social
# price_log                 4.78749
# Name: 205, dtype: object
#
# index is 206, row is:
# room_type              Private room
# price                            43
# experiences_offered        business
# price_log                    3.7612
# Name: 206, dtype: object
#
# index is 207, row is:
# room_type              Private room
# price                            60
# experiences_offered          social
# price_log                   4.09434
# Name: 207, dtype: object
#
# index is 208, row is:
# room_type              Private room
# price                            52
# experiences_offered          social
# price_log                   3.95124
# Name: 208, dtype: object
#
# index is 209, row is:
# room_type              Private room
# price                            20
# experiences_offered          social
# price_log                   2.99573
# Name: 209, dtype: object
#
# index is 210, row is:
# room_type              Private room
# price                            52
# experiences_offered        business
# price_log                   3.95124
# Name: 210, dtype: object
#
# index is 211, row is:
# room_type              Entire home/apt
# price                               60
# experiences_offered           business
# price_log                      4.09434
# Name: 211, dtype: object
#
# index is 212, row is:
# room_type              Entire home/apt
# price                              185
# experiences_offered             family
# price_log                      5.22036
# Name: 212, dtype: object
#
# index is 213, row is:
# room_type              Private room
# price                            89
# experiences_offered          family
# price_log                   4.48864
# Name: 213, dtype: object
#
# index is 214, row is:
# room_type              Private room
# price                            37
# experiences_offered        business
# price_log                   3.61092
# Name: 214, dtype: object
#
# index is 215, row is:
# room_type              Entire home/apt
# price                              179
# experiences_offered             family
# price_log                      5.18739
# Name: 215, dtype: object
#
# index is 216, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered             family
# price_log                      5.29832
# Name: 216, dtype: object
#
# index is 217, row is:
# room_type              Entire home/apt
# price                              190
# experiences_offered           business
# price_log                      5.24702
# Name: 217, dtype: object
#
# index is 218, row is:
# room_type              Private room
# price                            50
# experiences_offered          social
# price_log                   3.91202
# Name: 218, dtype: object
#
# index is 219, row is:
# room_type              Private room
# price                           150
# experiences_offered          social
# price_log                   5.01064
# Name: 219, dtype: object
#
# index is 220, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered             family
# price_log                      4.60517
# Name: 220, dtype: object
#
# index is 221, row is:
# room_type              Entire home/apt
# price                              150
# experiences_offered           romantic
# price_log                      5.01064
# Name: 221, dtype: object
#
# index is 222, row is:
# room_type              Entire home/apt
# price                              158
# experiences_offered             family
# price_log                      5.06259
# Name: 222, dtype: object
#
# index is 223, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 223, dtype: object
#
# index is 224, row is:
# room_type              Entire home/apt
# price                              170
# experiences_offered           business
# price_log                       5.1358
# Name: 224, dtype: object
#
# index is 225, row is:
# room_type              Private room
# price                            55
# experiences_offered          family
# price_log                   4.00733
# Name: 225, dtype: object
#
# index is 226, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered             family
# price_log                      4.70048
# Name: 226, dtype: object
#
# index is 227, row is:
# room_type              Private room
# price                            70
# experiences_offered        business
# price_log                    4.2485
# Name: 227, dtype: object
#
# index is 228, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered           business
# price_log                      4.60517
# Name: 228, dtype: object
#
# index is 229, row is:
# room_type              Private room
# price                            52
# experiences_offered        business
# price_log                   3.95124
# Name: 229, dtype: object
#
# index is 230, row is:
# room_type              Private room
# price                            67
# experiences_offered        business
# price_log                   4.20469
# Name: 230, dtype: object
#
# index is 231, row is:
# room_type              Private room
# price                            38
# experiences_offered        business
# price_log                   3.63759
# Name: 231, dtype: object
#
# index is 232, row is:
# room_type              Entire home/apt
# price                              115
# experiences_offered           romantic
# price_log                      4.74493
# Name: 232, dtype: object
#
# index is 233, row is:
# room_type              Private room
# price                            60
# experiences_offered          social
# price_log                   4.09434
# Name: 233, dtype: object
#
# index is 234, row is:
# room_type              Private room
# price                           168
# experiences_offered        business
# price_log                   5.12396
# Name: 234, dtype: object
#
# index is 235, row is:
# room_type              Private room
# price                            47
# experiences_offered          social
# price_log                   3.85015
# Name: 235, dtype: object
#
# index is 236, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 236, dtype: object
#
# index is 237, row is:
# room_type              Private room
# price                            70
# experiences_offered          social
# price_log                    4.2485
# Name: 237, dtype: object
#
# index is 238, row is:
# room_type              Private room
# price                            53
# experiences_offered          social
# price_log                   3.97029
# Name: 238, dtype: object
#
# index is 239, row is:
# room_type              Entire home/apt
# price                              155
# experiences_offered             social
# price_log                      5.04343
# Name: 239, dtype: object
#
# index is 240, row is:
# room_type              Private room
# price                            69
# experiences_offered        business
# price_log                   4.23411
# Name: 240, dtype: object
#
# index is 241, row is:
# room_type              Entire home/apt
# price                              173
# experiences_offered             family
# price_log                      5.15329
# Name: 241, dtype: object
#
# index is 242, row is:
# room_type              Private room
# price                            45
# experiences_offered        business
# price_log                   3.80666
# Name: 242, dtype: object
#
# index is 243, row is:
# room_type              Private room
# price                            35
# experiences_offered        business
# price_log                   3.55535
# Name: 243, dtype: object
#
# index is 244, row is:
# room_type              Private room
# price                            40
# ...
# price_log                      4.49981
# Name: 1468, dtype: object
#
# index is 1469, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered             family
# price_log                      4.70048
# Name: 1469, dtype: object
#
# index is 1470, row is:
# room_type              Entire home/apt
# price                               98
# experiences_offered             family
# price_log                      4.58497
# Name: 1470, dtype: object
#
# index is 1471, row is:
# room_type              Entire home/apt
# price                              171
# experiences_offered             family
# price_log                      5.14166
# Name: 1471, dtype: object
#
# index is 1472, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 1472, dtype: object
#
# index is 1473, row is:
# room_type              Private room
# price                            25
# experiences_offered          family
# price_log                   3.21888
# Name: 1473, dtype: object
#
# index is 1474, row is:
# room_type              Entire home/apt
# price                              300
# experiences_offered             social
# price_log                      5.70378
# Name: 1474, dtype: object
#
# index is 1475, row is:
# room_type              Entire home/apt
# price                              122
# experiences_offered             social
# price_log                      4.80402
# Name: 1475, dtype: object
#
# index is 1476, row is:
# room_type              Private room
# price                            40
# experiences_offered        business
# price_log                   3.68888
# Name: 1476, dtype: object
#
# index is 1477, row is:
# room_type              Entire home/apt
# price                               60
# experiences_offered             social
# price_log                      4.09434
# Name: 1477, dtype: object
#
# index is 1478, row is:
# room_type              Entire home/apt
# price                               75
# experiences_offered           business
# price_log                      4.31749
# Name: 1478, dtype: object
#
# index is 1479, row is:
# room_type              Private room
# price                            39
# experiences_offered        romantic
# price_log                   3.66356
# Name: 1479, dtype: object
#
# index is 1480, row is:
# room_type              Entire home/apt
# price                              145
# experiences_offered           business
# price_log                      4.97673
# Name: 1480, dtype: object
#
# index is 1481, row is:
# room_type              Entire home/apt
# price                               70
# experiences_offered           romantic
# price_log                       4.2485
# Name: 1481, dtype: object
#
# index is 1482, row is:
# room_type              Private room
# price                            55
# experiences_offered          social
# price_log                   4.00733
# Name: 1482, dtype: object
#
# index is 1483, row is:
# room_type              Private room
# price                            32
# experiences_offered          social
# price_log                   3.46574
# Name: 1483, dtype: object
#
# index is 1484, row is:
# room_type              Entire home/apt
# price                              220
# experiences_offered             family
# price_log                      5.39363
# Name: 1484, dtype: object
#
# index is 1485, row is:
# room_type              Private room
# price                            15
# experiences_offered          social
# price_log                   2.70805
# Name: 1485, dtype: object
#
# index is 1486, row is:
# room_type              Private room
# price                            15
# experiences_offered          social
# price_log                   2.70805
# Name: 1486, dtype: object
#
# index is 1487, row is:
# room_type              Entire home/apt
# price                              195
# experiences_offered             family
# price_log                        5.273
# Name: 1487, dtype: object
#
# index is 1488, row is:
# room_type              Private room
# price                            55
# experiences_offered        romantic
# price_log                   4.00733
# Name: 1488, dtype: object
#
# index is 1489, row is:
# room_type              Private room
# price                           140
# experiences_offered          social
# price_log                   4.94164
# Name: 1489, dtype: object
#
# index is 1490, row is:
# room_type              Entire home/apt
# price                               75
# experiences_offered           romantic
# price_log                      4.31749
# Name: 1490, dtype: object
#
# index is 1491, row is:
# room_type              Private room
# price                            37
# experiences_offered        business
# price_log                   3.61092
# Name: 1491, dtype: object
#
# index is 1492, row is:
# room_type              Entire home/apt
# price                              309
# experiences_offered             family
# price_log                      5.73334
# Name: 1492, dtype: object
#
# index is 1493, row is:
# room_type              Private room
# price                            60
# experiences_offered        business
# price_log                   4.09434
# Name: 1493, dtype: object
#
# index is 1494, row is:
# room_type              Private room
# price                            40
# experiences_offered          social
# price_log                   3.68888
# Name: 1494, dtype: object
#
# index is 1495, row is:
# room_type              Entire home/apt
# price                              119
# experiences_offered           business
# price_log                      4.77912
# Name: 1495, dtype: object
#
# index is 1496, row is:
# room_type              Entire home/apt
# price                              140
# experiences_offered           business
# price_log                      4.94164
# Name: 1496, dtype: object
#
# index is 1497, row is:
# room_type              Entire home/apt
# price                              215
# experiences_offered             family
# price_log                      5.37064
# Name: 1497, dtype: object
#
# index is 1498, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered           business
# price_log                      4.78749
# Name: 1498, dtype: object
#
# index is 1499, row is:
# room_type              Private room
# price                            70
# experiences_offered        business
# price_log                    4.2485
# Name: 1499, dtype: object
#
# index is 1500, row is:
# room_type              Private room
# price                            80
# experiences_offered          social
# price_log                   4.38203
# Name: 1500, dtype: object
#
# index is 1501, row is:
# room_type              Private room
# price                           130
# experiences_offered        business
# price_log                   4.86753
# Name: 1501, dtype: object
#
# index is 1502, row is:
# room_type              Private room
# price                            39
# experiences_offered        business
# price_log                   3.66356
# Name: 1502, dtype: object
#
# index is 1503, row is:
# room_type              Entire home/apt
# price                               48
# experiences_offered           romantic
# price_log                       3.8712
# Name: 1503, dtype: object
#
# index is 1504, row is:
# room_type              Private room
# price                            25
# experiences_offered          social
# price_log                   3.21888
# Name: 1504, dtype: object
#
# index is 1505, row is:
# room_type              Private room
# price                            56
# experiences_offered          social
# price_log                   4.02535
# Name: 1505, dtype: object
#
# index is 1506, row is:
# room_type              Entire home/apt
# price                               79
# experiences_offered           romantic
# price_log                      4.36945
# Name: 1506, dtype: object
#
# index is 1507, row is:
# room_type              Entire home/apt
# price                               51
# experiences_offered             family
# price_log                      3.93183
# Name: 1507, dtype: object
#
# index is 1508, row is:
# room_type              Entire home/apt
# price                              125
# experiences_offered           business
# price_log                      4.82831
# Name: 1508, dtype: object
#
# index is 1509, row is:
# room_type              Entire home/apt
# price                              239
# experiences_offered             family
# price_log                      5.47646
# Name: 1509, dtype: object
#
# index is 1510, row is:
# room_type              Entire home/apt
# price                              106
# experiences_offered             family
# price_log                      4.66344
# Name: 1510, dtype: object
#
# index is 1511, row is:
# room_type              Entire home/apt
# price                              108
# experiences_offered             family
# price_log                      4.68213
# Name: 1511, dtype: object
#
# index is 1512, row is:
# room_type              Entire home/apt
# price                              420
# experiences_offered             family
# price_log                      6.04025
# Name: 1512, dtype: object
#
# index is 1513, row is:
# room_type              Entire home/apt
# price                              270
# experiences_offered             family
# price_log                      5.59842
# Name: 1513, dtype: object
#
# index is 1514, row is:
# room_type              Entire home/apt
# price                               47
# experiences_offered           romantic
# price_log                      3.85015
# Name: 1514, dtype: object
#
# index is 1515, row is:
# room_type              Entire home/apt
# price                               90
# experiences_offered           business
# price_log                      4.49981
# Name: 1515, dtype: object
#
# index is 1516, row is:
# room_type              Private room
# price                            30
# experiences_offered          social
# price_log                    3.4012
# Name: 1516, dtype: object
#
# index is 1517, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             social
# price_log                      4.78749
# Name: 1517, dtype: object
#
# index is 1518, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 1518, dtype: object
#
# index is 1519, row is:
# room_type              Entire home/apt
# price                              220
# experiences_offered             family
# price_log                      5.39363
# Name: 1519, dtype: object
#
# index is 1520, row is:
# room_type              Entire home/apt
# price                              105
# experiences_offered           business
# price_log                      4.65396
# Name: 1520, dtype: object
#
# index is 1521, row is:
# room_type              Entire home/apt
# price                              185
# experiences_offered             family
# price_log                      5.22036
# Name: 1521, dtype: object
#
# index is 1522, row is:
# room_type              Private room
# price                           100
# experiences_offered          social
# price_log                   4.60517
# Name: 1522, dtype: object
#
# index is 1523, row is:
# room_type              Entire home/apt
# price                              215
# experiences_offered           romantic
# price_log                      5.37064
# Name: 1523, dtype: object
#
# index is 1524, row is:
# room_type              Private room
# price                            47
# experiences_offered        business
# price_log                   3.85015
# Name: 1524, dtype: object
#
# index is 1525, row is:
# room_type              Entire home/apt
# price                               64
# experiences_offered           romantic
# price_log                      4.15888
# Name: 1525, dtype: object
#
# index is 1526, row is:
# room_type              Private room
# price                            50
# experiences_offered          social
# price_log                   3.91202
# Name: 1526, dtype: object
#
# index is 1527, row is:
# room_type              Private room
# price                            70
# experiences_offered          social
# price_log                    4.2485
# Name: 1527, dtype: object
#
# index is 1528, row is:
# room_type              Entire home/apt
# price                               40
# experiences_offered           business
# price_log                      3.68888
# Name: 1528, dtype: object
#
# index is 1529, row is:
# room_type              Entire home/apt
# price                               80
# experiences_offered             social
# price_log                      4.38203
# Name: 1529, dtype: object
#
# index is 1530, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 1530, dtype: object
#
# index is 1531, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered           business
# price_log                      5.29832
# Name: 1531, dtype: object
#
# index is 1532, row is:
# room_type              Entire home/apt
# price                              200
# experiences_offered           romantic
# price_log                      5.29832
# Name: 1532, dtype: object
#
# index is 1533, row is:
# room_type              Entire home/apt
# price                              299
# experiences_offered           business
# price_log                      5.70044
# Name: 1533, dtype: object
#
# index is 1534, row is:
# room_type              Entire home/apt
# price                              391
# experiences_offered             family
# price_log                      5.96871
# Name: 1534, dtype: object
#
# index is 1535, row is:
# room_type              Entire home/apt
# price                              120
# experiences_offered             family
# price_log                      4.78749
# Name: 1535, dtype: object
#
# index is 1536, row is:
# room_type              Entire home/apt
# price                              145
# experiences_offered           business
# price_log                      4.97673
# Name: 1536, dtype: object
#
# index is 1537, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 1537, dtype: object
#
# index is 1538, row is:
# room_type              Private room
# price                            32
# experiences_offered          family
# price_log                   3.46574
# Name: 1538, dtype: object
#
# index is 1539, row is:
# room_type              Private room
# price                            30
# experiences_offered        business
# price_log                    3.4012
# Name: 1539, dtype: object
#
# index is 1540, row is:
# room_type              Private room
# price                            60
# experiences_offered          family
# price_log                   4.09434
# Name: 1540, dtype: object
#
# index is 1541, row is:
# room_type              Private room
# price                           100
# experiences_offered        romantic
# price_log                   4.60517
# Name: 1541, dtype: object
#
# index is 1542, row is:
# room_type              Private room
# price                            30
# experiences_offered          social
# price_log                    3.4012
# Name: 1542, dtype: object
#
# index is 1543, row is:
# room_type              Entire home/apt
# price                              100
# experiences_offered             family
# price_log                      4.60517
# Name: 1543, dtype: object
#
# index is 1544, row is:
# room_type              Entire home/apt
# price                              125
# experiences_offered           business
# price_log                      4.82831
# Name: 1544, dtype: object
#
# index is 1545, row is:
# room_type              Entire home/apt
# price                              185
# experiences_offered           business
# price_log                      5.22036
# Name: 1545, dtype: object
#
# index is 1546, row is:
# room_type              Entire home/apt
# price                              110
# experiences_offered           business
# price_log                      4.70048
# Name: 1546, dtype: object
#
# index is 1547, row is:
# room_type              Private room
# price                            39
# experiences_offered          social
# price_log                   3.66356
# Name: 1547, dtype: object

# %%
q_room_price_roma_query
# Out:
#             room_type  price experiences_offered  price_log
# 0        Private room   65.0            business   4.174387
# 1     Entire home/apt  100.0            romantic   4.605170
# 2        Private room  150.0            business   5.010635
# 3        Private room   45.0            business   3.806663
# 4        Private room   25.0            business   3.218876
# ...               ...    ...                 ...        ...
# 1543  Entire home/apt  100.0              family   4.605170
# 1544  Entire home/apt  125.0            business   4.828314
# 1545  Entire home/apt  185.0            business   5.220356
# 1546  Entire home/apt  110.0            business   4.700480
# 1547     Private room   39.0              social   3.663562
#
# [1548 rows x 4 columns]
